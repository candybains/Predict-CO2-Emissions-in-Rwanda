# %% [markdown]
# <a href="https://colab.research.google.com/github/candybains/Predict-CO2-Emissions-in-Rwanda/blob/main/Carbon_Emission.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import random
import os
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

from numpy import mean
from numpy import std
from sklearn.datasets import make_regression
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import RepeatedKFold
from xgboost import XGBRFRegressor
from sklearn.metrics import mean_absolute_error
import xgboost as xgb

from sklearn.svm import SVR
pd.options.display.float_format = '{:.5f}'.format
pd.options.display.max_rows = None
from matplotlib import pyplot as plt
import seaborn as sns
SEED = 2023
random.seed(SEED)
np.random.seed(SEED)

# %%
#!pip install scikit-learn==1.3.1

# %%
# Load files
train = pd.read_csv('/content/train.csv')
test = pd.read_csv('/content/test.csv')
samplesubmission = pd.read_csv('/content/sample_submission.csv')

# Preview train dataset
train.head()
# Out:
#        ID_LAT_LON_YEAR_WEEK  latitude  longitude  year  week_no  \
# 0  ID_-0.510_29.290_2019_00  -0.51000   29.29000  2019        0
# 1  ID_-0.510_29.290_2019_01  -0.51000   29.29000  2019        1
# 2  ID_-0.510_29.290_2019_02  -0.51000   29.29000  2019        2
# 3  ID_-0.510_29.290_2019_03  -0.51000   29.29000  2019        3
# 4  ID_-0.510_29.290_2019_04  -0.51000   29.29000  2019        4
#
#    SulphurDioxide_SO2_column_number_density  \
# 0                                  -0.00011
# 1                                   0.00002
# 2                                   0.00051
# 3                                       NaN
# 4                                  -0.00008
#
#    SulphurDioxide_SO2_column_number_density_amf  \
# 0                                       0.60302
# 1                                       0.72821
# 2                                       0.74820
# 3                                           NaN
# 4                                       0.67630
#
#    SulphurDioxide_SO2_slant_column_number_density  \
# 0                                        -0.00007
# 1                                         0.00001
# 2                                         0.00038
# 3                                             NaN
# 4                                        -0.00005
#
#    SulphurDioxide_cloud_fraction  SulphurDioxide_sensor_azimuth_angle  ...  \
# 0                        0.25567                            -98.59389  ...
# 1                        0.13099                             16.59286  ...
# 2                        0.11002                             72.79584  ...
# 3                            NaN                                  NaN  ...
# 4                        0.12116                              4.12127  ...
#
#    Cloud_cloud_top_height  Cloud_cloud_base_pressure  Cloud_cloud_base_height  \
# 0              3664.43622                61085.80957               2615.12048
# 1              3651.19031                66969.47873               3174.57242
# 2              4216.98649                60068.89445               3516.28267
# 3              5228.50774                51064.54734               4180.97332
# 4              3980.59812                63751.12578               3355.71011
#
#    Cloud_cloud_optical_depth  Cloud_surface_albedo  \
# 0                   15.56853               0.27229
# 1                    8.69060               0.25683
# 2                   21.10341               0.25110
# 3                   15.38690               0.26204
# 4                    8.11469               0.23585
#
#    Cloud_sensor_azimuth_angle  Cloud_sensor_zenith_angle  \
# 0                   -12.62899                   35.63242
# 1                    30.35938                   39.55763
# 2                    15.37788                   30.40182
# 3                   -11.29340                   24.38036
# 4                    38.53226                   37.39298
#
#    Cloud_solar_azimuth_angle  Cloud_solar_zenith_angle  emission
# 0                 -138.78642                  30.75214   3.75099
# 1                 -145.18393                  27.25178   4.02518
# 2                 -142.51954                  26.19330   4.23138
# 3                 -132.66583                  28.82915   4.30529
# 4                 -141.50981                  22.20461   4.34732
#
# [5 rows x 76 columns]

# %%
test.head()
# Out:
#        ID_LAT_LON_YEAR_WEEK  latitude  longitude  year  week_no  \
# 0  ID_-0.510_29.290_2022_00  -0.51000   29.29000  2022        0
# 1  ID_-0.510_29.290_2022_01  -0.51000   29.29000  2022        1
# 2  ID_-0.510_29.290_2022_02  -0.51000   29.29000  2022        2
# 3  ID_-0.510_29.290_2022_03  -0.51000   29.29000  2022        3
# 4  ID_-0.510_29.290_2022_04  -0.51000   29.29000  2022        4
#
#    SulphurDioxide_SO2_column_number_density  \
# 0                                       NaN
# 1                                   0.00046
# 2                                   0.00016
# 3                                   0.00035
# 4                                  -0.00032
#
#    SulphurDioxide_SO2_column_number_density_amf  \
# 0                                           NaN
# 1                                       0.69116
# 2                                       0.60511
# 3                                       0.69692
# 4                                       0.58053
#
#    SulphurDioxide_SO2_slant_column_number_density  \
# 0                                             NaN
# 1                                         0.00032
# 2                                         0.00011
# 3                                         0.00024
# 4                                        -0.00018
#
#    SulphurDioxide_cloud_fraction  SulphurDioxide_sensor_azimuth_angle  ...  \
# 0                            NaN                                  NaN  ...
# 1                        0.00000                             76.23920  ...
# 2                        0.07987                            -42.05534  ...
# 3                        0.20103                             72.16957  ...
# 4                        0.20435                             76.19086  ...
#
#    Cloud_cloud_top_pressure  Cloud_cloud_top_height  \
# 0               36022.02734              8472.31348
# 1               48539.73724              6476.14732
# 2               34133.08047              8984.79570
# 3               50854.99108              6014.72406
# 4               46594.68514              6849.28048
#
#    Cloud_cloud_base_pressure  Cloud_cloud_base_height  \
# 0                41047.93750               7472.31348
# 1                54915.70858               5476.14716
# 2                39006.09375               7984.79570
# 3                57646.36837               5014.72412
# 4                52896.54187               5849.28039
#
#    Cloud_cloud_optical_depth  Cloud_surface_albedo  \
# 0                    7.93562               0.24077
# 1                   11.44844               0.29312
# 2                   10.75318               0.26713
# 3                   11.76456               0.30468
# 4                   13.06532               0.28422
#
#    Cloud_sensor_azimuth_angle  Cloud_sensor_zenith_angle  \
# 0                  -100.11379                   33.69704
# 1                   -30.51032                   42.40259
# 2                    39.08736                   45.93648
# 3                   -24.46513                   42.14042
# 4                   -12.90785                   30.12264
#
#    Cloud_solar_azimuth_angle  Cloud_solar_zenith_angle
# 0                 -133.04755                  33.77958
# 1                 -138.63282                  31.01238
# 2                 -144.78499                  26.74336
# 3                 -135.02789                  29.60477
# 4                 -135.50012                  26.27681
#
# [5 rows x 75 columns]

# %%
train.shape, test.shape, samplesubmission.shape
# Out:
# ((79023, 76), (24353, 75), (24353, 2))

# %%
train['location'] = [str(x) + '_' + str(y) for x, y in zip(train.latitude, train.longitude)]

# Filter based on one location
example_loc = train[train.location == '-0.51_29.29']

# Calculate rolling mean for SulphurDioxide_SO2_column_number_density_amf with a window of 2 weeks
rolling_mean = example_loc['SulphurDioxide_SO2_column_number_density_amf'].rolling(window = 2).mean()

# Visualise rolling mean
plt.figure(figsize = (15, 7))
rolling_mean.plot()
plt.title('Rolling mean with a window of 2 weeks for SulphurDioxide_SO2_column_number_density_amf', y = 1.02, fontsize = 15)
plt.xlabel('week', y = 1.05, fontsize = 13)
plt.ylabel('SulphurDioxide_SO2_column_number_density_amf', x = 1.05, fontsize = 13)
plt.show()

# %%
train_roll_mean = train.sort_values(by = ['location', 'year', 'week_no']).groupby(['location'])[train.columns[5:].tolist()].rolling(window = 2).mean().reset_index()
train_roll_mean.drop(['level_1', 'emission', 'location'], axis = 1, inplace = True)
train_roll_mean.columns = [col + '_roll_mean' for col in train_roll_mean.columns]

# %%
test.latitude, test.longitude = round(test.latitude, 2), round(test.longitude, 2)
test['location'] = [str(x) + '_' + str(y) for x, y in zip(test.latitude, test.longitude)]

test_roll_mean = test.sort_values(by = ['location', 'year', 'week_no']).groupby(['location'])[test.columns[5:].tolist()].rolling(window = 2).mean().reset_index()
test_roll_mean.drop(['level_1', 'location'], axis = 1, inplace = True)
test_roll_mean.columns = [col + '_roll_mean' for col in test_roll_mean.columns]
test_roll_mean.head()
# Out:
#    SulphurDioxide_SO2_column_number_density_roll_mean  \
# 0                                                NaN
# 1                                                NaN
# 2                                            0.00031
# 3                                            0.00026
# 4                                            0.00002
#
#    SulphurDioxide_SO2_column_number_density_amf_roll_mean  \
# 0                                                NaN
# 1                                                NaN
# 2                                            0.64814
# 3                                            0.65101
# 4                                            0.63872
#
#    SulphurDioxide_SO2_slant_column_number_density_roll_mean  \
# 0                                                NaN
# 1                                                NaN
# 2                                            0.00021
# 3                                            0.00017
# 4                                            0.00003
#
#    SulphurDioxide_cloud_fraction_roll_mean  \
# 0                                      NaN
# 1                                      NaN
# 2                                  0.03993
# 3                                  0.14045
# 4                                  0.20269
#
#    SulphurDioxide_sensor_azimuth_angle_roll_mean  \
# 0                                            NaN
# 1                                            NaN
# 2                                       17.09193
# 3                                       15.05711
# 4                                       74.18022
#
#    SulphurDioxide_sensor_zenith_angle_roll_mean  \
# 0                                           NaN
# 1                                           NaN
# 2                                      27.74483
# 3                                      49.37580
# 4                                      37.25428
#
#    SulphurDioxide_solar_azimuth_angle_roll_mean  \
# 0                                           NaN
# 1                                           NaN
# 2                                    -138.71941
# 3                                    -144.95421
# 4                                    -144.39710
#
#    SulphurDioxide_solar_zenith_angle_roll_mean  \
# 0                                          NaN
# 1                                          NaN
# 2                                     29.47540
# 3                                     25.93065
# 4                                     23.06746
#
#    SulphurDioxide_SO2_column_number_density_15km_roll_mean  \
# 0                                                NaN
# 1                                                NaN
# 2                                            0.00011
# 3                                            0.00007
# 4                                            0.00001
#
#    CarbonMonoxide_CO_column_number_density_roll_mean  ...  \
# 0                                                NaN  ...
# 1                                                NaN  ...
# 2                                            0.03772  ...
# 3                                            0.03877  ...
# 4                                            0.03949  ...
#
#    Cloud_cloud_top_pressure_roll_mean  Cloud_cloud_top_height_roll_mean  \
# 0                                 NaN                               NaN
# 1                         42280.88229                        7474.23040
# 2                         41336.40886                        7730.47151
# 3                         42494.03577                        7499.75988
# 4                         48724.83811                        6432.00227
#
#    Cloud_cloud_base_pressure_roll_mean  Cloud_cloud_base_height_roll_mean  \
# 0                                  NaN                                NaN
# 1                          47981.82304                         6474.23032
# 2                          46960.90116                         6730.47143
# 3                          48326.23106                         6499.75991
# 4                          55271.45512                         5432.00225
#
#    Cloud_cloud_optical_depth_roll_mean  Cloud_surface_albedo_roll_mean  \
# 0                                  NaN                             NaN
# 1                              9.69203                         0.26695
# 2                             11.10081                         0.28012
# 3                             11.25887                         0.28590
# 4                             12.41494                         0.29445
#
#    Cloud_sensor_azimuth_angle_roll_mean  Cloud_sensor_zenith_angle_roll_mean  \
# 0                                   NaN                                  NaN
# 1                             -65.31206                             38.04982
# 2                               4.28852                             44.16954
# 3                               7.31112                             44.03845
# 4                             -18.68649                             36.13153
#
#    Cloud_solar_azimuth_angle_roll_mean  Cloud_solar_zenith_angle_roll_mean
# 0                                  NaN                                 NaN
# 1                           -135.84018                            32.39598
# 2                           -141.70891                            28.87787
# 3                           -139.90644                            28.17407
# 4                           -135.26400                            27.94079
#
# [5 rows x 70 columns]

# %%
train_eng = train.sort_values(by = ['location', 'year', 'week_no'], ignore_index = True).merge(train_roll_mean, how = 'left',
                                                                                               left_index=True, right_index=True)
# Test
test_eng = test.sort_values(by = ['location', 'year', 'week_no'], ignore_index = True).merge(test_roll_mean, how = 'left',
                                                                                               left_index=True, right_index=True)
# Preview engineered test set
test_eng.head()
# Out:
#        ID_LAT_LON_YEAR_WEEK  latitude  longitude  year  week_no  \
# 0  ID_-0.510_29.290_2022_00  -0.51000   29.29000  2022        0
# 1  ID_-0.510_29.290_2022_01  -0.51000   29.29000  2022        1
# 2  ID_-0.510_29.290_2022_02  -0.51000   29.29000  2022        2
# 3  ID_-0.510_29.290_2022_03  -0.51000   29.29000  2022        3
# 4  ID_-0.510_29.290_2022_04  -0.51000   29.29000  2022        4
#
#    SulphurDioxide_SO2_column_number_density  \
# 0                                       NaN
# 1                                   0.00046
# 2                                   0.00016
# 3                                   0.00035
# 4                                  -0.00032
#
#    SulphurDioxide_SO2_column_number_density_amf  \
# 0                                           NaN
# 1                                       0.69116
# 2                                       0.60511
# 3                                       0.69692
# 4                                       0.58053
#
#    SulphurDioxide_SO2_slant_column_number_density  \
# 0                                             NaN
# 1                                         0.00032
# 2                                         0.00011
# 3                                         0.00024
# 4                                        -0.00018
#
#    SulphurDioxide_cloud_fraction  SulphurDioxide_sensor_azimuth_angle  ...  \
# 0                            NaN                                  NaN  ...
# 1                        0.00000                             76.23920  ...
# 2                        0.07987                            -42.05534  ...
# 3                        0.20103                             72.16957  ...
# 4                        0.20435                             76.19086  ...
#
#    Cloud_cloud_top_pressure_roll_mean  Cloud_cloud_top_height_roll_mean  \
# 0                                 NaN                               NaN
# 1                         42280.88229                        7474.23040
# 2                         41336.40886                        7730.47151
# 3                         42494.03577                        7499.75988
# 4                         48724.83811                        6432.00227
#
#    Cloud_cloud_base_pressure_roll_mean  Cloud_cloud_base_height_roll_mean  \
# 0                                  NaN                                NaN
# 1                          47981.82304                         6474.23032
# 2                          46960.90116                         6730.47143
# 3                          48326.23106                         6499.75991
# 4                          55271.45512                         5432.00225
#
#    Cloud_cloud_optical_depth_roll_mean  Cloud_surface_albedo_roll_mean  \
# 0                                  NaN                             NaN
# 1                              9.69203                         0.26695
# 2                             11.10081                         0.28012
# 3                             11.25887                         0.28590
# 4                             12.41494                         0.29445
#
#    Cloud_sensor_azimuth_angle_roll_mean  Cloud_sensor_zenith_angle_roll_mean  \
# 0                                   NaN                                  NaN
# 1                             -65.31206                             38.04982
# 2                               4.28852                             44.16954
# 3                               7.31112                             44.03845
# 4                             -18.68649                             36.13153
#
#    Cloud_solar_azimuth_angle_roll_mean  Cloud_solar_zenith_angle_roll_mean
# 0                                  NaN                                 NaN
# 1                           -135.84018                            32.39598
# 2                           -141.70891                            28.87787
# 3                           -139.90644                            28.17407
# 4                           -135.26400                            27.94079
#
# [5 rows x 146 columns]

# %%
X = train_eng.drop(['ID_LAT_LON_YEAR_WEEK', 'location', 'emission'], axis = 1).fillna(0)
y = train_eng.emission

# Splitting the data into training and testing sets

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = SEED)

# Instantiating the model
clf = RandomForestRegressor(random_state = SEED, n_jobs=-1)
clf.fit(X_train, y_train)
# Out:
# RandomForestRegressor(n_jobs=-1, random_state=2023)

# %%
y_pred = clf.predict(X_test)

# %%
print(f'RMSE Score: {mean_squared_error(y_test, y_pred)}')
# Out:
# RMSE Score: 754.7381979025614

# %%
X_test.head()
# Out:
#        latitude  longitude  year  week_no  \
# 42962  -1.96800   30.93200  2019       32
# 20489  -1.32700   30.97300  2021       31
# 49300  -2.17100   28.62900  2019       10
# 13289  -1.11700   29.88300  2020       39
# 31375  -1.64100   31.25900  2019       52
#
#        SulphurDioxide_SO2_column_number_density  \
# 42962                                  -0.00031
# 20489                                  -0.00005
# 49300                                   0.00008
# 13289                                   0.00000
# 31375                                   0.00004
#
#        SulphurDioxide_SO2_column_number_density_amf  \
# 42962                                       0.71053
# 20489                                       0.83240
# 49300                                       0.82463
# 13289                                       0.00000
# 31375                                       0.75535
#
#        SulphurDioxide_SO2_slant_column_number_density  \
# 42962                                        -0.00022
# 20489                                        -0.00004
# 49300                                         0.00006
# 13289                                         0.00000
# 31375                                         0.00003
#
#        SulphurDioxide_cloud_fraction  SulphurDioxide_sensor_azimuth_angle  \
# 42962                        0.05047                             16.57960
# 20489                        0.10846                             17.56284
# 49300                        0.09100                             74.80393
# 13289                        0.00000                              0.00000
# 31375                        0.22451                             75.46359
#
#        SulphurDioxide_sensor_zenith_angle  ...  \
# 42962                            45.51030  ...
# 20489                            35.96635  ...
# 49300                            32.09079  ...
# 13289                             0.00000  ...
# 31375                            25.12664  ...
#
#        Cloud_cloud_top_pressure_roll_mean  Cloud_cloud_top_height_roll_mean  \
# 42962                         57419.29103                        5330.79123
# 20489                         61520.93314                        4065.66013
# 49300                         48901.16490                        4626.37383
# 13289                         52079.15598                        5787.26982
# 31375                         44224.48788                        7041.88831
#
#        Cloud_cloud_base_pressure_roll_mean  Cloud_cloud_base_height_roll_mean  \
# 42962                          61552.54148                         4654.78256
# 20489                          69494.58153                         3112.44794
# 49300                          54412.81630                         3896.92843
# 13289                          58881.23696                         4798.99914
# 31375                          50164.00427                         6057.84949
#
#        Cloud_cloud_optical_depth_roll_mean  Cloud_surface_albedo_roll_mean  \
# 42962                             10.79548                         0.24813
# 20489                             10.74455                         0.21591
# 49300                             24.60350                         0.26977
# 13289                             28.16117                         0.26420
# 31375                             15.27048                         0.26619
#
#        Cloud_sensor_azimuth_angle_roll_mean  \
# 42962                             -31.46791
# 20489                               6.19150
# 49300                              -2.84187
# 13289                              10.87889
# 31375                              11.59058
#
#        Cloud_sensor_zenith_angle_roll_mean  \
# 42962                             47.36010
# 20489                             43.89503
# 49300                             38.80104
# 13289                             40.55605
# 31375                             37.11346
#
#        Cloud_solar_azimuth_angle_roll_mean  Cloud_solar_zenith_angle_roll_mean
# 42962                            -49.75059                            28.81543
# 20489                            -43.85110                            28.08377
# 49300                            -98.31160                            19.79850
# 13289                            -92.68547                            23.21665
# 31375                           -140.04970                            29.57884
#
# [5 rows x 144 columns]

# %%
pred_errors = X_test.copy()
pred_errors['emission'] = y_test
pred_errors['prediction'] = y_pred
pred_errors['error'] = abs(pred_errors.prediction - pred_errors.emission)
pred_errors = pred_errors[['latitude',	'longitude',	'year',	'week_no', 'emission', 'prediction', 'error']]
pred_errors.sort_values(by = 'error', ascending = False, inplace = True)
pred_errors.head()
# Out:
#        latitude  longitude  year  week_no   emission  prediction      error
# 46437  -2.07900   29.32100  2019        9 1044.48450  2923.74516 1879.26066
# 46490  -2.07900   29.32100  2020        9 1011.02600  2796.08616 1785.06016
# 56674  -2.37800   29.22200  2020       17 1502.66770  2084.31089  581.64319
# 56679  -2.37800   29.22200  2020       22 1689.61380  2224.19779  534.58399
# 56671  -2.37800   29.22200  2020       14 1777.71030  2244.72893  467.01863

# %%
pred_errors.tail()
# Out:
#        latitude  longitude  year  week_no  emission  prediction   error
# 33952  -1.73000   28.47000  2020       32   0.00000     0.00000 0.00000
# 70779  -2.84100   29.15900  2019       24   0.00000     0.00000 0.00000
# 28263  -1.53200   28.56800  2021       14   0.00000     0.00000 0.00000
# 33355  -1.71200   28.68800  2021       18   0.00000     0.00000 0.00000
# 26608  -1.50500   30.99500  2020        2   0.00000     0.00000 0.00000

# %%
#X, y = make_regression(n_samples=1000, n_features=20, n_informative=15, noise=0.1, random_state=7)
D_train = xgb.DMatrix(X_train, label=y_train)

param = {
    'eta': 0.1,
    'reg_lambda' : 1.5,
    'max_depth': 500
    }

steps = 100


model = xgb.train(param, D_train, steps)

# model = XGBRFRegressor(tree_method="hist", eval_metric = mean_squared_error, random_state = SEED, n_jobs=-1)
# model.fit(X_train, y_train)

# %%
D_test = xgb.DMatrix(X_test)
y_xgb_pred = model.predict(D_test)

# %%
print(f'RMSE Score: {mean_squared_error(y_test, y_xgb_pred)}')
# Out:
# RMSE Score: 560.5289511953702

# %%
#pip install SuperTree

# %%
# from supertree import SuperTree

# st = SuperTree(
#     model,
#     X,
#     y
# )
# # Visualize the tree
# st.show_tree(which_tree=1)

# %%
D_test

# %%
pred_errors = X_test.copy()
pred_errors['emission'] = y_test
pred_errors['prediction'] = y_xgb_pred
pred_errors['error'] = abs(pred_errors.prediction - pred_errors.emission)
pred_errors = pred_errors[['latitude',	'longitude',	'year',	'week_no', 'emission', 'prediction', 'error']]
pred_errors.sort_values(by = 'error', ascending = False, inplace = True)
pred_errors.head()
# Out:
#        latitude  longitude  year  week_no   emission  prediction      error
# 46543  -2.07900   29.32100  2021        9 2730.65900   931.89325 1798.76575
# 56674  -2.37800   29.22200  2020       17 1502.66770  2133.84229  631.17459
# 56679  -2.37800   29.22200  2020       22 1689.61380  2143.86987  454.25607
# 56671  -2.37800   29.22200  2020       14 1777.71030  2208.51953  430.80923
# 56727  -2.37800   29.22200  2021       17 2016.59630  2391.44312  374.84682

# %%
test_df = test_eng.drop(['ID_LAT_LON_YEAR_WEEK', 'location'], axis = 1).fillna(0)
D_test_df = xgb.DMatrix(test_df)
predictions = model.predict(D_test_df)

# # Create a submission file
sub_file = pd.DataFrame({'ID_LAT_LON_YEAR_WEEK': test_eng.ID_LAT_LON_YEAR_WEEK, 'emission': predictions})
sub_file.head()
# Out:
#        ID_LAT_LON_YEAR_WEEK  emission
# 0  ID_-0.510_29.290_2022_00   4.21162
# 1  ID_-0.510_29.290_2022_01   4.44930
# 2  ID_-0.510_29.290_2022_02   4.46393
# 3  ID_-0.510_29.290_2022_03   4.39398
# 4  ID_-0.510_29.290_2022_04   4.52510

# %%
test_df['emission'] = predictions
test_df.head()
# Out:
#    latitude  longitude  year  week_no  \
# 0  -0.51000   29.29000  2022        0
# 1  -0.51000   29.29000  2022        1
# 2  -0.51000   29.29000  2022        2
# 3  -0.51000   29.29000  2022        3
# 4  -0.51000   29.29000  2022        4
#
#    SulphurDioxide_SO2_column_number_density  \
# 0                                   0.00000
# 1                                   0.00046
# 2                                   0.00016
# 3                                   0.00035
# 4                                  -0.00032
#
#    SulphurDioxide_SO2_column_number_density_amf  \
# 0                                       0.00000
# 1                                       0.69116
# 2                                       0.60511
# 3                                       0.69692
# 4                                       0.58053
#
#    SulphurDioxide_SO2_slant_column_number_density  \
# 0                                         0.00000
# 1                                         0.00032
# 2                                         0.00011
# 3                                         0.00024
# 4                                        -0.00018
#
#    SulphurDioxide_cloud_fraction  SulphurDioxide_sensor_azimuth_angle  \
# 0                        0.00000                              0.00000
# 1                        0.00000                             76.23920
# 2                        0.07987                            -42.05534
# 3                        0.20103                             72.16957
# 4                        0.20435                             76.19086
#
#    SulphurDioxide_sensor_zenith_angle  ...  \
# 0                             0.00000  ...
# 1                            15.60061  ...
# 2                            39.88906  ...
# 3                            58.86254  ...
# 4                            15.64602  ...
#
#    Cloud_cloud_base_pressure_roll_mean  Cloud_cloud_base_height_roll_mean  \
# 0                              0.00000                            0.00000
# 1                          47981.82304                         6474.23032
# 2                          46960.90116                         6730.47143
# 3                          48326.23106                         6499.75991
# 4                          55271.45512                         5432.00225
#
#    Cloud_cloud_optical_depth_roll_mean  Cloud_surface_albedo_roll_mean  \
# 0                              0.00000                         0.00000
# 1                              9.69203                         0.26695
# 2                             11.10081                         0.28012
# 3                             11.25887                         0.28590
# 4                             12.41494                         0.29445
#
#    Cloud_sensor_azimuth_angle_roll_mean  Cloud_sensor_zenith_angle_roll_mean  \
# 0                               0.00000                              0.00000
# 1                             -65.31206                             38.04982
# 2                               4.28852                             44.16954
# 3                               7.31112                             44.03845
# 4                             -18.68649                             36.13153
#
#    Cloud_solar_azimuth_angle_roll_mean  Cloud_solar_zenith_angle_roll_mean  \
# 0                              0.00000                             0.00000
# 1                           -135.84018                            32.39598
# 2                           -141.70891                            28.87787
# 3                           -139.90644                            28.17407
# 4                           -135.26400                            27.94079
#
#    Emission  emission
# 0   4.21162   4.21162
# 1   4.44930   4.44930
# 2   4.46393   4.46393
# 3   4.39398   4.39398
# 4   4.52510   4.52510
#
# [5 rows x 146 columns]

# %%
# @title year vs latitude

from matplotlib import pyplot as plt
import seaborn as sns
def _plot_series(series, series_name, series_index=0):
  palette = list(sns.palettes.mpl_palette('Dark2'))
  xs = series['week_no']
  ys = series['emission']


  plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])

fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
df_sorted = test_df.sort_values(['year','week_no'], ascending=True)
df_sorted = df_sorted[df_sorted['longitude']==29.29000]
_plot_series(df_sorted, '')
#sns.despine(fig=fig, ax=ax)
plt.xlabel('Week')
_ = plt.ylabel('emission')

fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
df_train = train.sort_values(['year','week_no'], ascending=True)
df_train = train[(train['longitude']==29.29000) & (train['year']==2021)]
_plot_series(df_train, '')
#sns.despine(fig=fig, ax=ax)
plt.xlabel('Week')
_ = plt.ylabel('emission')

# %%
pip install plotly
# Out:
# Requirement already satisfied: plotly in /usr/local/lib/python3.11/dist-packages (5.24.1)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.11/dist-packages (from plotly) (9.0.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from plotly) (24.2)

# %%
import plotly.graph_objects as go

fig = go.Figure()

df_sorted = test_df.sort_values(['year','week_no'], ascending=True)
df_sorted = df_sorted[df_sorted['longitude']==29.29000]
# add trace only for first stock
x = df_sorted['week_no']
y = df_sorted['emission']
fig.add_traces(go.Scatter(x=x, y=y))


button_labels = test_df['longitude']

# Generating visibility settings for dropdown buttons
visibility = [
    [i == j for j in range(len(button_labels))]
    for i in range(len(button_labels))
]

# Creating the dropdown buttons
buttons = [
    {
        "label": button_labels[i],
        "method": "update",
        "args": [
            {"visible": visibility[i]},
            {"title": button_labels[i]}
        ]
    }
    for i in range(len(button_labels))
]

updatemenus = [{'buttons': buttons,
                'direction': 'down',
                'showactive': True,}]

# update layout with buttons, and show the figure
fig.update_layout(updatemenus=updatemenus)
fig.show()

# %%
sub_file.to_csv('BaselineSubmission.csv', index = False)

# %%
df_sorted[df_sorted['longitude'] == 29.29000]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-e5244c3b195b> in <cell line: 0>()
# ----> 1 df_sorted[df_sorted['longitude'] == 29.29000]
#
# NameError: name 'df_sorted' is not defined
